# %%
import pandas as p

# %%
p.read_excel("‪C:\Users\HP\Desktop\nishu.xlsx")
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_8508\666655352.py", line 1
#     p.read_excel("‪C:\Users\HP\Desktop\nishu.xlsx")
#                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 12-13: truncated \UXXXXXXXX escape
