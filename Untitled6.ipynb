# %%
import pandas as p

# %%
p.read_csv(r"C:\Users\HP\Desktop\Nishu.tsv",sep='\t')
# Out:
#   name phonenumber batchnumber
# 0      bob  1354443543  python
# 1        allen 1313213213 java
# 2        alex  33132131   c++

# %%
p.read_csv(r'C:\Users\HP\Desktop\nishank.tsv',sep='\t')
# Out:
#    name   batch  rollno.
# 0  alex  python    12135
